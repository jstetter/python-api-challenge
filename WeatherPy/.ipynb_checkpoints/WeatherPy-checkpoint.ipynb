# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# %%
from api_keys import api_key

# %%
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
# Output File (CSV)
output_data_file = "output_data/cities.csv"

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
 # List for holding lat_lngs and cities
lat_lngs = []
cities = []

# %%
# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# %%
# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 749

# %% [markdown]
# # Perform API Calls
#
# Perform a weather check on each city using a series of successive API calls.
#
# Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# %%
lattitude_lst = []
windspeed_lst = []
humidity_lst = []
cloudiness_lst = []
temperature_lst = []
name_lst = []
number = 1

# %%
for city in cities:
    try:
        query_url = f"{url}appid={api_key}&units={units}&q={city}"
        response = requests.get(query_url).json()
        lattitude_lst.append(response['coord']['lat'])
        windspeed_lst.append(response['wind']['speed'])
        humidity_lst.append(response['main']['humidity'])
        cloudiness_lst.append(response['clouds']['all'])
        temperature_lst.append(response['main']['temp'])
        name_lst.append(city.title())
        print(f'City number {number} is {city.title()}')
        number += 1
    except:
        number -= 1
    if number > 500:
        break
# Out:
# City number 1 is rikitea
# City number 2 is ribeira grande
# City number 3 is nyurba
# City number 4 is suvorovskaya
# City number 5 is bathsheba
# City number 6 is iqaluit
# City number 7 is ilulissat
# City number 8 is vaini
# City number 9 is jamestown
# City number 10 is bonito
# City number 10 is bluff
# City number 10 is yar-sale
# City number 11 is cape town
# City number 12 is yenagoa
# City number 13 is ushuaia
# City number 14 is barrow
# City number 15 is nicoya
# City number 16 is nanortalik
# City number 17 is busselton
# City number 18 is karratha
# City number 19 is mataura
# City number 20 is punta arenas
# City number 21 is naze
# City number 22 is cuamba
# City number 23 is socorro
# City number 24 is somerset east
# City number 25 is avarua
# City number 26 is thompson
# City number 27 is samarai
# City number 28 is olinda
# City number 29 is georgetown
# City number 30 is nishihara
# City number 31 is upernavik
# City number 32 is cidreira
# City number 32 is grindavik
# City number 33 is chuy
# City number 34 is geraldton
# City number 35 is san martin
# City number 36 is katsuura
# City number 37 is werota
# City number 38 is obo
# City number 39 is lebu
# City number 40 is castro
# City number 41 is ambilobe
# City number 42 is coihaique
# City number 43 is kodiak
# City number 44 is tasiilaq
# City number 45 is kobyzhcha
# City number 46 is margate
# City number 47 is khatanga
# City number 48 is pochutla
# City number 49 is mersing
# City number 49 is hamilton
# City number 50 is umarkot
# City number 51 is tilichiki
# City number 52 is vila franca do campo
# City number 53 is ancud
# City number 54 is guane
# City number 55 is qaanaaq
# City number 55 is petropavlovsk-kamchatskiy
# City number 56 is almaznyy
# City number 57 is pendleton
# City number 58 is new norfolk
# City number 59 is touba
# City number 60 is bethel
# City number 61 is ponta delgada
# City number 62 is erzurum
# City number 63 is butaritari
# City number 64 is hami
# City number 65 is oromocto
# City number 66 is hithadhoo
# City number 67 is omsukchan
# City number 68 is harper
# City number 69 is puerto ayora
# City number 69 is wanning
# City number 70 is hasaki
# City number 71 is port alfred
# City number 72 is albany
# City number 73 is port blair
# City number 74 is pedro juan caballero
# City number 73 is komsomolskiy
# City number 74 is artigas
# City number 75 is bara
# City number 76 is chumikan
# City number 77 is maragogi
# City number 78 is santa vitoria do palmar
# City number 79 is pangnirtung
# City number 80 is saint-philippe
# City number 81 is cabo san lucas
# City number 82 is lubango
# City number 83 is baykit
# City number 84 is ferme-neuve
# City number 85 is isangel
# City number 86 is gravdal
# City number 87 is gizo
# City number 88 is bilibino
# City number 89 is arlit
# City number 89 is hilo
# City number 90 is port keats
# City number 91 is nome
# City number 92 is yellowknife
# City number 93 is kavieng
# City number 94 is beloha
# City number 95 is ahipara
# City number 96 is port elizabeth
# City number 97 is cherskiy
# City number 97 is aklavik
# City number 98 is vanavara
# City number 99 is luderitz
# City number 100 is jarvakandi
# City number 101 is gawler
# City number 102 is atuona
# City number 102 is palmer
# City number 103 is hermanus
# City number 104 is saint anthony
# City number 105 is dharchula
# City number 106 is riyadh
# City number 107 is san policarpo
# City number 108 is tuktoyaktuk
# City number 109 is chirongui
# City number 110 is hofn
# City number 111 is gdov
# City number 112 is torbay
# City number 113 is heihe
# City number 114 is kloulklubed
# City number 115 is bandundu
# City number 116 is corralillo
# City number 117 is judaberg
# City number 118 is soure
# City number 119 is kargasok
# City number 120 is kaitangata
# City number 121 is carnarvon
# City number 122 is iskateley
# City number 123 is kapaa
# City number 124 is saskylakh
# City number 125 is rognan
# City number 126 is griffith
# City number 127 is zboriste
# City number 128 is durres
# City number 129 is acapulco
# City number 130 is niort
# City number 130 is faanui
# City number 131 is dalvik
# City number 131 is laguna
# City number 132 is jiwani
# City number 133 is pevek
# City number 134 is kuusamo
# City number 135 is arcata
# City number 136 is vigo
# City number 137 is hovd
# City number 138 is dali
# City number 139 is kruisfontein
# City number 140 is nioro
# City number 141 is prince rupert
# City number 142 is udachnyy
# City number 143 is mar del plata
# City number 144 is sao filipe
# City number 145 is timra
# City number 146 is severo-kurilsk
# City number 147 is constitucion
# City number 148 is sola
# City number 149 is mocuba
# City number 150 is saint george
# City number 151 is butzbach
# City number 152 is mitsamiouli
# City number 153 is bambous virieux
# City number 153 is havelock
# City number 154 is bandarbeyla
# City number 155 is ardmore
# City number 156 is usinsk
# City number 157 is hobart
# City number 157 is vaitape
# City number 158 is vila velha
# City number 159 is karad
# City number 160 is egvekinot
# City number 161 is iquitos
# City number 162 is nenjiang
# City number 162 is sabang
# City number 162 is provideniya
# City number 163 is plouzane
# City number 164 is nuuk
# City number 165 is mackay
# City number 166 is lagoa
# City number 167 is port-gentil
# City number 168 is vung tau
# City number 168 is victoria
# City number 168 is harvard
# City number 169 is tiksi
# City number 170 is rock springs
# City number 171 is kuraymah
# City number 171 is punta alta
# City number 172 is hun
# City number 173 is walvis bay
# City number 174 is gushikawa
# City number 175 is tuatapere
# City number 176 is fortuna
# City number 177 is bowral
# City number 176 is thunder bay
# City number 177 is angoche
# City number 178 is matagami
# City number 179 is san quintin
# City number 179 is mogadishu
# City number 180 is baldeo
# City number 178 is ewa beach
# City number 179 is souillac
# City number 180 is verkhniy ufaley
# City number 181 is lyngseidet
# City number 182 is mareeba
# City number 183 is sitka
# City number 184 is sainte-suzanne
# City number 184 is marrakesh
# City number 185 is sosnovoborsk
# City number 185 is tiznit
# City number 186 is yumen
# City number 187 is chokurdakh
# City number 188 is lasa
# City number 189 is whitehorse
# City number 190 is salalah
# City number 191 is aasiaat
# City number 192 is astana
# City number 192 is grand gaube
# City number 193 is coquimbo
# City number 194 is fort collins
# City number 195 is chacabuco
# City number 196 is pilar
# City number 197 is kota kinabalu
# City number 196 is valentin gomez farias
# City number 197 is nikolskoye
# City number 198 is taoudenni
# City number 199 is port macquarie
# City number 200 is veraval
# City number 201 is los llanos de aridane
# City number 202 is neepawa
# City number 203 is khammam
# City number 204 is odessa
# City number 205 is basco
# City number 206 is carutapera
# City number 207 is frutal
# City number 208 is mahebourg
# City number 209 is altay
# City number 210 is houston
# City number 211 is turbat
# City number 211 is santa rosa
# City number 212 is luanda
# City number 213 is mount gambier
# City number 214 is konstantynow lodzki
# City number 215 is sobolevo
# City number 215 is haines junction
# City number 216 is klaksvik
# City number 217 is xam nua
# City number 218 is bayan
# City number 219 is vao
# City number 220 is methoni
# City number 221 is lima
# City number 222 is beyneu
# City number 223 is pangody
# City number 224 is vikulovo
# City number 225 is buraydah
# City number 226 is acari
# City number 227 is elmadag
# City number 228 is ankazoabo
# City number 229 is vestmannaeyjar
# City number 230 is inuvik
# City number 231 is sept-iles
# City number 232 is guerrero negro
# City number 233 is vikhorevka
# City number 234 is la ronge
# City number 235 is dikson
# City number 236 is acucena
# City number 237 is marawi
# City number 238 is mayumba
# City number 239 is arraial do cabo
# City number 240 is kutum
# City number 241 is bredasdorp
# City number 242 is labuhan
# City number 243 is bud
# City number 244 is lashio
# City number 245 is gusau
# City number 246 is bosobolo
# City number 247 is ostrovnoy
# City number 248 is maceio
# City number 249 is tokmak
# City number 249 is lerwick
# City number 250 is verkhoyansk
# City number 250 is chelno-vershiny
# City number 251 is two rivers
# City number 252 is dunedin
# City number 253 is norman wells
# City number 253 is natal
# City number 254 is adrar
# City number 255 is buala
# City number 256 is cabanas
# City number 257 is trairi
# City number 258 is lucea
# City number 259 is gold coast
# City number 260 is narsaq
# City number 261 is bilma
# City number 262 is goderich
# City number 263 is buin
# City number 263 is boda
# City number 264 is talnakh
# City number 265 is lukang
# City number 266 is abay
# City number 267 is verkhnevilyuysk
# City number 268 is cristalina
# City number 269 is lac du bonnet
# City number 270 is tual
# City number 269 is razdolinsk
# City number 269 is evensk
# City number 270 is gubkinskiy
# City number 271 is east london
# City number 272 is aldan
# City number 273 is starobesheve
# City number 274 is mount isa
# City number 275 is seguela
# City number 275 is pangai
# City number 276 is aginskoye
# City number 277 is diffa
# City number 278 is didwana
# City number 278 is toktogul
# City number 279 is uberaba
# City number 280 is serenje
# City number 281 is camacha
# City number 282 is port hardy
# City number 283 is atasu
# City number 284 is shimoda
# City number 285 is dauriya
# City number 286 is maues
# City number 287 is alofi
# City number 288 is airai
# City number 289 is port lincoln
# City number 290 is karanja
# City number 291 is jalu
# City number 292 is bosaso
# City number 293 is charters towers
# City number 293 is buchanan
# City number 294 is piacabucu
# City number 295 is waingapu
# City number 296 is leningradskiy
# City number 297 is kenitra
# City number 298 is bereznik
# City number 297 is susehri
# City number 298 is clyde river
# City number 299 is san patricio
# City number 299 is meadow lake
# City number 300 is deputatskiy
# City number 301 is lompoc
# City number 302 is umm kaddadah
# City number 303 is sioux lookout
# City number 304 is batemans bay
# City number 305 is podosinovets
# City number 306 is jutai
# City number 307 is boguchany
# City number 307 is nantucket
# City number 308 is boueni
# City number 309 is beringovskiy
# City number 310 is palitana
# City number 311 is kerman
# City number 312 is aksha
# City number 313 is ketchikan
# City number 314 is tiarei
# City number 315 is aksarka
# City number 316 is pokhara
# City number 317 is calamagui
# City number 318 is san jeronimo
# City number 319 is albanel
# City number 320 is payette
# City number 321 is dudinka
# City number 322 is wamba
# City number 323 is saiha
# City number 324 is nouakchott
# City number 325 is sirvintos
# City number 326 is saint-francois
# City number 327 is husavik
# City number 328 is te anau
# City number 329 is hatfield
# City number 330 is lander
# City number 331 is imeni poliny osipenko
# City number 332 is bitung
# City number 333 is watsa
# City number 334 is bonthe
# City number 335 is kavaratti
# City number 336 is voh
# City number 337 is bonavista
# City number 338 is alakurtti
# City number 339 is fairbanks
# City number 340 is saldanha
# City number 341 is kununurra
# City number 341 is bougouni
# City number 342 is son la
# City number 342 is novyy urengoy
# City number 342 is rocha
# City number 343 is kaeo
# City number 344 is kattivakkam
# City number 344 is san cristobal
# City number 345 is warri
# City number 346 is noumea
# City number 347 is corner brook
# City number 347 is douglas
# City number 348 is oksfjord
# City number 349 is barra velha
# City number 349 is bubaque
# City number 350 is sanlucar de barrameda
# City number 351 is almenara
# City number 351 is wuning
# City number 352 is ucluelet
# City number 353 is sechura
# City number 354 is dalen
# City number 355 is huarmey
# City number 356 is longyearbyen
# City number 357 is baykalovo
# City number 358 is sao felix do xingu
# City number 359 is kargopol
# City number 360 is lovozero
# City number 360 is birao
# City number 361 is amga
# City number 362 is moerai
# City number 363 is stillwater
# City number 364 is jian
# City number 365 is bima
# City number 366 is ayan
# City number 367 is manta
# City number 367 is sovetskiy
# City number 368 is rio grande
# City number 369 is sardinia
# City number 370 is banjar
# City number 371 is luis correia
# City number 371 is aranos
# City number 371 is key west
# City number 372 is oussouye
# City number 373 is halifax
# City number 374 is esperance
# City number 375 is high level
# City number 376 is eureka
# City number 377 is zhuhai
# City number 377 is bhuj
# City number 377 is lazarev
# City number 377 is codrington
# City number 378 is mehamn
# City number 379 is shetpe
# City number 380 is kaili
# City number 381 is tahoua
# City number 382 is mandalgovi
# City number 383 is xai-xai
# City number 384 is praia
# City number 385 is sandwick
# City number 386 is ola
# City number 387 is tokoroa
# City number 388 is namibe
# City number 389 is dinard
# City number 390 is mateare
# City number 391 is beni
# City number 392 is wewak
# City number 393 is tonantins
# City number 394 is yokadouma
# City number 395 is paris
# City number 396 is itarema
# City number 397 is khani
# City number 398 is nova olimpia
# City number 399 is mahibadhoo
# City number 400 is paka
# City number 401 is qaqortoq
# City number 402 is aksu
# City number 403 is perth
# City number 404 is tsiroanomandidy
# City number 405 is ratnagiri
# City number 406 is miraflores
# City number 407 is negombo
# City number 408 is valenca
# City number 409 is yarada
# City number 410 is marfino
# City number 411 is takatsuki
# City number 412 is kasongo
# City number 413 is pathein
# City number 414 is comodoro rivadavia
# City number 415 is middle island
# City number 416 is ponta do sol
# City number 417 is flinders
# City number 418 is muros
# City number 419 is ongandjera
# City number 420 is vanimo
# City number 421 is north bend
# City number 422 is nushki
# City number 423 is abha
# City number 424 is tabuk
# City number 425 is mayo
# City number 426 is kropotkin
# City number 427 is touros
# City number 428 is ukiah
# City number 429 is nhulunbuy
# City number 430 is yuanping
# City number 431 is salinopolis
# City number 432 is axim
# City number 433 is kumluca
# City number 434 is konevo
# City number 435 is port augusta
# City number 436 is sinnamary
# City number 437 is tupik
# City number 438 is terrace bay
# City number 439 is santa maria
# City number 440 is george town
# City number 441 is altamira
# City number 442 is yichang
# City number 442 is tres arroyos
# City number 443 is chalmeca
# City number 444 is xichang
# City number 444 is fayaoue
# City number 445 is jieshi
# City number 446 is lodwar
# City number 447 is staryy nadym
# City number 448 is roald
# City number 449 is lavrentiya
# City number 449 is bastia
# City number 450 is den helder
# City number 451 is srednekolymsk
# City number 452 is sur
# City number 453 is palana
# City number 454 is storforshei
# City number 455 is shanhetun
# City number 456 is ilo
# City number 457 is dostpur
# City number 458 is flagstaff
# City number 459 is portland
# City number 460 is bajil
# City number 461 is phuket
# City number 461 is thinadhoo
# City number 461 is raudeberg
# City number 462 is hudson bay
# City number 463 is konyshevka
# City number 464 is vadso
# City number 465 is mumford
# City number 466 is praya
# City number 467 is rach gia
# City number 468 is grootfontein
# City number 469 is tam ky
# City number 470 is poroshkovo
# City number 471 is savalou
# City number 472 is gerash
# City number 473 is senanga
# City number 474 is vacaria
# City number 475 is sabha
# City number 476 is biak
# City number 477 is snezhnogorsk
# City number 478 is aykhal
# City number 479 is golden
# City number 480 is hanzhong
# City number 481 is oktyabrskoye
# City number 482 is solnechnyy
# City number 483 is mahon
# City number 484 is kasiri
# City number 485 is rio gallegos
# City number 486 is caravelas
# City number 487 is tarakan
# City number 488 is coruripe
# City number 489 is padang
# City number 490 is auki
# City number 491 is hoa binh
# City number 492 is along
# City number 493 is sokolo
# City number 494 is moindou
# City number 495 is sikonge
# City number 496 is yeppoon
# City number 497 is christchurch
# City number 498 is esso
# City number 499 is omboue
# City number 500 is cayenne

# %% [markdown]
#  # Convert Raw Data to DataFrame
#
# Export the city data into a .csv.
#
# Display the DataFrame

# %%
df = pd.DataFrame({'City': name_lst, 'Lattitude': lattitude_lst, 'Windspeed': windspeed_lst, 'Humidity':humidity_lst, 'Cloudiness':cloudiness_lst, 'Temperature': temperature_lst})
df.head()
# Out:
#              City  Lattitude  Windspeed  Humidity  Cloudiness  Temperature
# 0         rikitea     -23.12      18.99        80          67        76.08
# 1  ribeira grande      38.52      17.92        90         100        60.58
# 2          nyurba      63.29       1.25        98         100       -14.55
# 3    suvorovskaya      44.19       6.71        92          75        17.24
# 4       bathsheba      13.22      10.29        78          40        77.00

# %%
df.to_csv('weather_data.csv', index = False)

# %% [markdown]
# # Plotting the Data
#
# Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# Save the plotted figures as .pngs.

# %% [markdown]
# Latitude vs. Temperature Plot

# %%
plt.scatter(df['Lattitude'], df['Temperature'])
plt.title('')

# %% [markdown]
# Latitude vs. Humidity Plot

# %%
plt.scatter(df['Lattitude'], df['Humidity'])
plt.title('Latitude vs. Humidity (%)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
# Out:
# Text(0, 0.5, 'Humidity (%)')

# %% [markdown]
# Latitude vs. Cloudiness Plot

# %%
plt.scatter(df['Lattitude'], df['Cloudiness'])
plt.title('Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
# Out:
# Text(0, 0.5, 'Cloudiness (%)')

# %% [markdown]
# Latitude vs. Wind Speed Plot

# %%
plt.scatter(df['Lattitude'], df['Windspeed'])
plt.title('Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
# Out:
# Text(0, 0.5, 'Wind Speed (mph)')
